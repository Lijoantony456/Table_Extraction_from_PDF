# %% [markdown]
# pdfplumber is a Python library for extracting information, including text and tables, from PDF documents.We used it for extracting the text to view the content in the pdf

# %%
# !pip install pdfplumber -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 901.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 36.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 60.0 MB/s eta 0:00:00

# %% [markdown]
# ### "ocrmypdf" is an external command-line tool used for adding OCR (Optical Character Recognition) text to PDF files. It takes an input PDF file, processes it to recognize text in images, and outputs a new PDF file with the recognized text.

# %%
# !apt-get install ocrmypdf -q
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript icc-profiles-free libgs9
#   libgs9-common libidn12 libijs-0.35 libimagequant0 libjbig2dec0 libqpdf28 libraqm0 mailcap
#   mime-support pngquant poppler-data python3-bs4 python3-chardet python3-coloredlogs
#   python3-html5lib python3-humanfriendly python3-img2pdf python3-lxml python3-olefile
#   python3-packaging python3-pdfminer python3-pikepdf python3-pil python3-pluggy python3-renderpm
#   python3-reportlab python3-reportlab-accel python3-soupsieve python3-tqdm python3-webencodings
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd unpaper
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x ocrmypdf-doc
#   python-watchdog img2pdf poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
# ...

# %% [markdown]
# ###Camelot is a Python library used for extracting tables from PDF documents.  Camelot is designed to handle tables in PDFs with varying complexities and structures.

# %%
pip install camelot-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 987.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.6/277.6 kB 5.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ###Camelot relies on Ghostscript as one of its backends for processing PDF files. Camelot uses Ghostscript to rasterize the PDF pages, making it easier to identify table structures and extract tabular data.

# %%
pip install ghostscript

# %%
#importing necessary libraries
import os
import pdfplumber
import re
import pandas as pd
import camelot
import ghostscript

# %%
invoice = '/content/Pdf_3.pdf'

# %%
os.system(f'ocrmypdf {invoice} output.pdf')
# Out:
# 0

# %%
#to display the content in the pdf
with pdfplumber.open('output.pdf') as pdf:
  page = pdf.pages[0]
  text = page.extract_text(x_tolerance=2)
  print(text)
# Out:
# K
# i Da FUNG Solution
# ——
# Nd (PG0344765-V)
# Malaysia / Singapore / Thailand Office
# 303-4-11, Jalan Thean Teik
# 5200128 EF 11500 Ayer Itam
# Pulau Pinang, Malaysia
# Mobile: 6 016-428 0240
# F251 Fax; 604-684 9482
# Email: dafungsolution@yahoo.com
# (PG0344765-V)
# TA X INVOICE Please Always Quote: GST 1D:000568188928
# ————__ Invoice No.: INV 1159
# Date: 24-Dec-19
# Bill To:
# CYPRESS SEMICONDUCTOR (M) SDN. BHD. Customer PO No. : 3300004655
# (FKA SPANSION (PENANG) SDN. BHD.) DO No.: . DO 1159
# Phase II, FIZ,
# Payment Terms: Net 60 days due
# Bayan Lepas,
# Pulau Pinang, 11900 Sales Rep. name: Ooi Yit Chieuh
# Malaysia Add ies To:
# Attn: Account Payable / Finance Dept Address Queries To:
# Mr. Ooi Yit Chieuh
# Mobile: +6016-428 0240
# E-mail:dafungsolution@yahoo.com
# Item.| Description Q uantity Unit Price Total Price
# Product Code Ordered Shipped B/O RM RM
# 1. | Supplier Item: 1 1 4,219.50 4,219.50
# Ref#DF 0198/11/19Q
# 1.Pump Y-2951.0467
# ...

# %%
#using camelot we try to extract the table.
tables  = camelot.read_pdf("/content/output.pdf",flavor="lattice")
tables[0].df[:]
# Out:
#         0                                         1  \
# 0  Item.|               Description \nProduct  Code
# 1
# 2      1.  |  Supplier  Item: \nRef#DF  0198/11/19Q
# 3
# 4
# 5
# 6
# 7
#
#                               2 3    4                 5                  6
# 0                                       Unit  Price \nRM  Total  Price \nRM
# 1  Quantity \nShipped \nOrdered    B/O
# 2                         1 \n1                 4,219.50           4,219.50
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# ###As we can see the table extracted is not completely reliable. Not all the table data is extracted
